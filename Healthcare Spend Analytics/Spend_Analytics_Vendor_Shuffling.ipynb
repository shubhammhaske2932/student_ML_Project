# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Final_Dataset_V2.csv")
df.head()
# Out:
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# 1              315                     DZ                         DZ
# 2              372                     EA                         EA
# 3              351                     EA                         EA
# 4              347                     EA                         EA
#
#   Vendor_Name Vendor_ID  ... Contract_Start_Date Contract_End_Date  \
# 0     WellSky      V135  ...          29-06-2021        26-11-2022
# ...

# %%
df['Item_Description'].nunique()
# Out:
# 54

# %%
df1 = df.iloc[0:300,:]
df1.tail()
# Out:
#         PO_Date PO_Number Item_ID Item_Description  \
# 295  24-09-2022    PO0296    IT21    Surgical Mask
# 296  24-05-2022    PO0297    IT22      Oxygen Mask
# 297  20-12-2021    PO0298    IT23          Dropper
# 298  11-02-2022    PO0299    IT24           Needle
# 299  19-11-2021    PO0300    IT25             Cane
#
#                       Manufacturer_Name  Manufacturer_ID  \
# 295                   Poly Medicure Ltd              318
# 296            Ribbel International Ltd              378
# 297                    Advin Healthcare              324
# 298  Aegis Lifesciences Private Limited              398
# 299                      Smiths Medical              365
#
#     Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure Vendor_Name Vendor_ID  \
# 295                  PK100                      PK100     WellSky      V135
# 296                   PK50                       PK50       Rivet      V672
# 297                     EA                         EA     FGA Inc      V522
# ...

# %%
df2 = df.iloc[300:600,:]
df2.head()
# Out:
#         PO_Date PO_Number Item_ID  Item_Description     Manufacturer_Name  \
# 300  25-09-2021    PO0301    IT26   Surgical Clamps       Cardinal Health
# 301  08-08-2022    PO0302    IT27           Forceps      Becton Dickinson
# 302  06-12-2021    PO0303    IT28    Surgical Table      General Electric
# 303  18-05-2021    PO0304    IT29     Utility Table         Medtronic PLC
# 304  07-08-2022    PO0305    IT30  Instrument Table  Siemens Healthineers
#
#      Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 300              372                     EA                         EA
# 301              390                     DZ                         DZ
# 302              350                     EA                         EA
# 303              335                     EA                         EA
# 304              307                     EA                         EA
#
#          Vendor_Name Vendor_ID  ... Contract_Start_Date Contract_End_Date  \
# ...

# %%
df2["New_Vendor_Name"]=df2['Item_Description']
df2.head()
# Out:
# C:\Users\ShubhamM3\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#         PO_Date PO_Number Item_ID  Item_Description     Manufacturer_Name  \
# 300  25-09-2021    PO0301    IT26   Surgical Clamps       Cardinal Health
# 301  08-08-2022    PO0302    IT27           Forceps      Becton Dickinson
# 302  06-12-2021    PO0303    IT28    Surgical Table      General Electric
# 303  18-05-2021    PO0304    IT29     Utility Table         Medtronic PLC
# 304  07-08-2022    PO0305    IT30  Instrument Table  Siemens Healthineers
#
#      Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# ...

# %%
df2['New_Vendor_Name'] = df2['New_Vendor_Name'].map({'Stethscope':"Ritiko LLC", 'Scissor':"Ability Network", 'Stretcher':"Prevounce Health", 'Magnifier':'Noble House',
       'Weighing Scale':'eSolutions', 'Torch':"Experian Health Inc", 'Face Mask':"Eligible Inc", 'First Aid Kit':"Cerner Health Services HDX", 'Gloves':"myhELO",
       'Scalpel':"Toyon Associates Inc", 'Microscope':"Healthcare IP", 'Otoscope':"WellSky", 'Thermometer':"Rivet", 'Saline Bag':"FGA Inc",
       'Syringe':"Quadax Inc", 'X-ray Machine':"OmniSys", 'Bandag':"Etactics", 'Crutches':"HealthXNet", 'Plaster':"CompMed",
       'Cotton Wool':"Ritiko LLC", 'Surgical Mask':"Ability Network", 'Oxygen Mask':"Prevounce Healt", 'Dropper':"Prevounce Healt", 'Needle':"eSolutions",
       'Cane':"Experian Health Inc", 'Surgical Clamps':"Eligible Inc", 'Forceps':"Cerner Health Services HDX", 'Surgical Table':"myhELO",
       'Utility Table':"Toyon Associates Inc", 'Instrument Table':"Healthcare IP", 'Ventilator':"WellSky", 'Mayo Stands':"Rivet",
       'Kickbuckets':"FGA Inc", 'Arm Supports':"Quadax Inc", 'Medical Syringe Infusion':"OmniSys",
       'Pacemakers':"Etactics", 'Defibrillators':"HealthXNet", 'Wheelchairs':"CompMed",
       'Traction Equipment':"Ritiko LLC", 'Needle Holder':"Ability Network", 'Medicine Cup':"Prevounce Health", 'Gauze':"Noble House",
       'Trays':"eSolutions", 'Cotton Swabs':"Experian Health Inc", 'Surgical lights':"Eligible Inc", 'Anesthesia machine':"Cerner Health Services HDX",
       'Walkers':"myhELO", 'Tourniquet':"Toyon Associates Inc", 'Splints':"Healthcare IP", 'Slings':"WellSky", 'ECG Machine':"Rivet",
       'Nebulizers':"FGA Inc", 'Sutures':"Quadax Inc", 'Braces':"OmniSys"})
# Out:
# C:\Users\ShubhamM3\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
df3['Item_Description'].nunique()
# Out:
# 54

# %%
df3 = df.iloc[600:850,:]
df3
# Out:
#         PO_Date PO_Number Item_ID Item_Description  \
# 600  24-09-2022    PO0601    IT51           Slings
# 601  20-10-2022    PO0602    IT52      ECG Machine
# 602  29-01-2022    PO0603    IT53       Nebulizers
# 603  19-10-2021    PO0604    IT54          Sutures
# 604  13-07-2021    PO0605    IT55           Braces
# 605  18-05-2022    PO0606     IT1       Stethscope
# 606  19-11-2022    PO0607     IT2          Scissor
# 607  19-07-2021    PO0608     IT3        Stretcher
# 608  30-08-2021    PO0609     IT4        Magnifier
# 609  04-07-2021    PO0610     IT5   Weighing Scale
# 610  28-12-2021    PO0611     IT6            Torch
# 611  05-04-2022    PO0612     IT7        Face Mask
# 612  06-09-2021    PO0613     IT8    First Aid Kit
# 613  18-05-2021    PO0614     IT9           Gloves
# 614  19-01-2022    PO0615    IT10          Scalpel
# 615  30-08-2021    PO0616    IT11       Microscope
# 616  14-12-2021    PO0617    IT12         Otoscope
# ...

# %%
df3["New_Vendor_Name"]=df3['Item_Description']
df3.head()
# Out:
# C:\Users\ShubhamM3\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#         PO_Date PO_Number Item_ID Item_Description  \
# 600  24-09-2022    PO0601    IT51           Slings
# 601  20-10-2022    PO0602    IT52      ECG Machine
# 602  29-01-2022    PO0603    IT53       Nebulizers
# 603  19-10-2021    PO0604    IT54          Sutures
# 604  13-07-2021    PO0605    IT55           Braces
#
#                       Manufacturer_Name  Manufacturer_ID  \
# 600                   Poly Medicure Ltd              318
# 601            Ribbel International Ltd              378
# 602                    Advin Healthcare              324
# ...

# %%
df3['New_Vendor_Name'] = df3['New_Vendor_Name'].map({'Stethscope':"WellSky", 'Scissor':"Rivet", 'Stretcher':"FGA Inc", 'Magnifier':'Quadax Inc',
       'Weighing Scale':'OmniSys', 'Torch':"Etactics",'Face Mask':"HealthXNet", 'First Aid Kit':"CompMed", 'Gloves':"Ritiko LLC",
       'Scalpel':"Ability Network", 'Microscope':"Prevounce Health", 'Otoscope':"Noble House",'Thermometer':"eSolutions", 'Saline Bag':"Experian Health Inc",
       'Syringe':"Eligible Inc", 'X-ray Machine':"Cerner Health Services HDX", 'Bandag':"myhELO", 'Crutches':"Toyon Associates Inc", 'Plaster':"Healthcare IP",
       'Cotton Wool':"WellSky", 'Surgical Mask':"Rivet", 'Oxygen Mask':"FGA Inc",'Dropper':"Quadax Inc", 'Needle':"OmniSys",'Cane':"Etactics", 'Surgical Clamps':"HealthXNet", 
 'Forceps':"CompMed", 'Surgical Table':"Ritiko LLC",'Utility Table':"Ability Network", 'Instrument Table':"Prevounce Health", 'Ventilator':"Experian Health Inc", 
 'Mayo Stands':"Eligible Inc",'Kickbuckets':"Cerner Health Services HDX", 'Arm Supports':"myhELO", 'Medical Syringe Infusion':"Toyon Associates Inc",
       'Pacemakers':"Healthcare IP", 'Defibrillators':"WellSky", 'Wheelchairs':"Rivet",'Traction Equipment':"FGA Inc", 'Needle Holder':"Quadax Inc", 'Medicine Cup':"OmniSys", 'Gauze':"Etactics",
       'Trays':"HealthXNet", 'Cotton Swabs':"CompMed", 'Surgical lights':"Ritiko LLC",'Anesthesia machine':"Ability Network",'Walkers':"Prevounce Health", 'Tourniquet':"Noble House", 
 'Splints':"eSolutions", 'Slings':"Experian Health Inc", 'ECG Machine':"Eligible Inc",'Nebulizers':"Cerner Health Services HDX", 'Sutures':"myhELO", 'Braces':"Toyon Associates Inc"})
# Out:
# C:\Users\ShubhamM3\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df3
# Out:
#         PO_Date PO_Number Item_ID Item_Description  \
# 600  24-09-2022    PO0601    IT51           Slings
# 601  20-10-2022    PO0602    IT52      ECG Machine
# 602  29-01-2022    PO0603    IT53       Nebulizers
# 603  19-10-2021    PO0604    IT54          Sutures
# 604  13-07-2021    PO0605    IT55           Braces
# 605  18-05-2022    PO0606     IT1       Stethscope
# 606  19-11-2022    PO0607     IT2          Scissor
# 607  19-07-2021    PO0608     IT3        Stretcher
# 608  30-08-2021    PO0609     IT4        Magnifier
# 609  04-07-2021    PO0610     IT5   Weighing Scale
# 610  28-12-2021    PO0611     IT6            Torch
# 611  05-04-2022    PO0612     IT7        Face Mask
# 612  06-09-2021    PO0613     IT8    First Aid Kit
# 613  18-05-2021    PO0614     IT9           Gloves
# 614  19-01-2022    PO0615    IT10          Scalpel
# 615  30-08-2021    PO0616    IT11       Microscope
# 616  14-12-2021    PO0617    IT12         Otoscope
# ...

# %%
{'Stethscope':"WellSky", 'Scissor':"Rivet", 'Stretcher':"FGA Inc", 'Magnifier':'Quadax Inc',
       'Weighing Scale':'OmniSys', 'Torch':"Etactics",'Face Mask':"HealthXNet", 'First Aid Kit':"CompMed", 'Gloves':"Ritiko LLC",
       'Scalpel':"Ability Network", 'Microscope':"Prevounce Health", 'Otoscope':"Noble House",'Thermometer':"eSolutions", 'Saline Bag':"Experian Health Inc",
       'Syringe':"Eligible Inc", 'X-ray Machine':"Cerner Health Services HDX", 'Bandag':"myhELO", 'Crutches':"Toyon Associates Inc", 'Plaster':"Healthcare IP",
       'Cotton Wool':"WellSky", 'Surgical Mask':"Rivet", 'Oxygen Mask':"FGA Inc",'Dropper':"Quadax Inc", 'Needle':"OmniSys",'Cane':"Etactics", 'Surgical Clamps':"HealthXNet", 
 'Forceps':"CompMed", 'Surgical Table':"Ritiko LLC",'Utility Table':"Ability Network", 'Instrument Table':"Prevounce Health", 'Ventilator':"Experian Health Inc", 
 'Mayo Stands':"Eligible Inc",'Kickbuckets':"Cerner Health Services HDX", 'Arm Supports':"myhELO", 'Medical Syringe Infusion':"Toyon Associates Inc",
       'Pacemakers':"Healthcare IP", 'Defibrillators':"WellSky", 'Wheelchairs':"Rivet",'Traction Equipment':"FGA Inc", 'Needle Holder':"Quadax Inc", 'Medicine Cup':"OmniSys", 'Gauze':"Etactics",
       'Trays':"HealthXNet", 'Cotton Swabs':"CompMed", 'Surgical lights':"Ritiko LLC",'Anesthesia machine':"Ability Network",'Walkers':"Prevounce Health", 'Tourniquet':"Noble House", 
 'Splints':"eSolutions", 'Slings':"Experian Health Inc", 'ECG Machine':"Eligible Inc",'Nebulizers':"Cerner Health Services HDX", 'Sutures':"myhELO", 'Braces':"Toyon Associates Inc"}

# %%
df2['Vendor_Name'].unique()
# Out:
# array(['Etactics', 'HealthXNet', 'CompMed', 'Ritiko LLC',
#        'Ability Network', 'Prevounce Health', 'Noble House', 'eSolutions',
#        'Experian Health Inc', 'Eligible Inc',
#        'Cerner Health Services HDX', 'myhELO', 'Toyon Associates Inc',
#        'Healthcare IP', 'WellSky', 'Rivet', 'FGA Inc', 'Quadax Inc',
#        'OmniSys'], dtype=object)

# %%
df4 = df.iloc[850:,:]
df4.head()
# Out:
#         PO_Date PO_Number Item_ID  Item_Description     Manufacturer_Name  \
# 850  06-04-2021    PO0851    IT26   Surgical Clamps       Cardinal Health
# 851  08-07-2021    PO0852    IT27           Forceps      Becton Dickinson
# 852  19-01-2022    PO0853    IT28    Surgical Table      General Electric
# 853  11-08-2021    PO0854    IT29     Utility Table         Medtronic PLC
# 854  25-07-2021    PO0855    IT30  Instrument Table  Siemens Healthineers
#
#      Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 850              372                     EA                         EA
# 851              390                     DZ                         DZ
# 852              350                     EA                         EA
# 853              335                     EA                         EA
# 854              307                     EA                         EA
#
#          Vendor_Name Vendor_ID  ... Contract_Start_Date Contract_End_Date  \
# ...

# %%
df4["New_Vendor_Name"]=df4['Item_Description']
df4.head()
# Out:
# C:\Users\ShubhamM3\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#         PO_Date PO_Number Item_ID  Item_Description     Manufacturer_Name  \
# 850  06-04-2021    PO0851    IT26   Surgical Clamps       Cardinal Health
# 851  08-07-2021    PO0852    IT27           Forceps      Becton Dickinson
# 852  19-01-2022    PO0853    IT28    Surgical Table      General Electric
# 853  11-08-2021    PO0854    IT29     Utility Table         Medtronic PLC
# 854  25-07-2021    PO0855    IT30  Instrument Table  Siemens Healthineers
#
#      Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# ...

# %%
df4['Item_Description'].nunique()
# Out:
# 54

# %%
{'Stethscope':"WellSky", 'Scissor':"Rivet", 'Stretcher':"eSolutions", 'Magnifier':'Quadax Inc',
       'Weighing Scale':'OmniSys', 'Torch':"Etactics",'Face Mask':"Etactics", 'First Aid Kit':"CompMed", 'Gloves':"Ritiko LLC",
       'Scalpel':"Ability Network", 'Microscope':"Prevounce Health", 'Otoscope':"Quadax Inc",'Thermometer':"Healthcare IP", 'Saline Bag':"Experian Health Inc",
       'Syringe':"Rivet", 'X-ray Machine':"Cerner Health Services HDX", 'Bandag':"Cerner Health Services HDX", 'Crutches':"Toyon Associates Inc", 'Plaster':"CompMed",
       'Cotton Wool':"WellSky", 'Surgical Mask':"Rivet", 'Oxygen Mask':"FGA Inc",'Dropper':"Quadax Inc", 'Needle':"OmniSys",'Cane':"Etactics", 'Surgical Clamps':"HealthXNet", 
 'Forceps':"CompMed", 'Surgical Table':"Ritiko LLC",'Utility Table':"Ability Network", 'Instrument Table':"Prevounce Health", 'Ventilator':"Toyon Associates Inc", 
 'Mayo Stands':"Eligible Inc",'Kickbuckets':"Cerner Health Services HDX", 'Arm Supports':"myhELO", 'Medical Syringe Infusion':"Toyon Associates Inc",
       'Pacemakers':"Etactics", 'Defibrillators':"Ritiko LLC", 'Wheelchairs':"Rivet",'Traction Equipment':"FGA Inc", 'Needle Holder':"FGA Inc", 'Medicine Cup':"HealthXNet", 'Gauze':"Etactics",
       'Trays':"HealthXNet", 'Cotton Swabs':"CompMed", 'Surgical lights':"Ritiko LLC",'Anesthesia machine':"myhELO",'Walkers':"Prevounce Health", 'Tourniquet':"Noble House", 
 'Splints':"Prevounce Health", 'Slings':"Experian Health Inc", 'ECG Machine':"myhELO",'Nebulizers':"Cerner Health Services HDX", 'Sutures':"myhELO", 'Braces':"Toyon Associates Inc"}

# %%
df['Vendor_Name'].unique()
# Out:
# array(['WellSky', 'Rivet', 'FGA Inc', 'Quadax Inc', 'OmniSys', 'Etactics',
#        'HealthXNet', 'CompMed', 'Ritiko LLC', 'Ability Network',
#        'Prevounce Health', 'Noble House', 'eSolutions',
#        'Experian Health Inc', 'Eligible Inc',
#        'Cerner Health Services HDX', 'myhELO', 'Toyon Associates Inc',
#        'Healthcare IP'], dtype=object)

# %%
df4['New_Vendor_Name'] = df4['New_Vendor_Name'].map({'Stethscope':"WellSky", 'Scissor':"Rivet", 'Stretcher':"eSolutions", 'Magnifier':'Quadax Inc',
       'Weighing Scale':'OmniSys', 'Torch':"Etactics",'Face Mask':"Etactics", 'First Aid Kit':"CompMed", 'Gloves':"Ritiko LLC",
       'Scalpel':"Ability Network", 'Microscope':"Prevounce Health", 'Otoscope':"Quadax Inc",'Thermometer':"Healthcare IP", 'Saline Bag':"Experian Health Inc",
       'Syringe':"Rivet", 'X-ray Machine':"Cerner Health Services HDX", 'Bandag':"Cerner Health Services HDX", 'Crutches':"Toyon Associates Inc", 'Plaster':"CompMed",
           'Cotton Wool':"WellSky", 'Surgical Mask':"Rivet", 'Oxygen Mask':"FGA Inc",'Dropper':"Quadax Inc", 'Needle':"OmniSys",'Cane':"Etactics", 'Surgical Clamps':"HealthXNet", 
 'Forceps':"CompMed", 'Surgical Table':"Ritiko LLC",'Utility Table':"Ability Network", 'Instrument Table':"Prevounce Health", 'Ventilator':"Toyon Associates Inc", 
 'Mayo Stands':"Eligible Inc",'Kickbuckets':"Cerner Health Services HDX", 'Arm Supports':"myhELO", 'Medical Syringe Infusion':"Toyon Associates Inc",
       'Pacemakers':"Etactics", 'Defibrillators':"Ritiko LLC", 'Wheelchairs':"Rivet",'Traction Equipment':"FGA Inc", 'Needle Holder':"FGA Inc", 'Medicine Cup':"HealthXNet", 'Gauze':"Etactics",
       'Trays':"HealthXNet", 'Cotton Swabs':"CompMed", 'Surgical lights':"Ritiko LLC",'Anesthesia machine':"myhELO",'Walkers':"Prevounce Health", 'Tourniquet':"Noble House", 
 'Splints':"Prevounce Health", 'Slings':"Experian Health Inc", 'ECG Machine':"myhELO",'Nebulizers':"Cerner Health Services HDX", 'Sutures':"myhELO", 'Braces':"Toyon Associates Inc"})
# Out:
# C:\Users\ShubhamM3\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
len(df1),len(df2),len(df3),len(df4)
# Out:
# (300, 300, 250, 150)

# %%
df1["New_Vendor_Name"]=df1['Vendor_Name']
df1.head()
# Out:
# C:\Users\ShubhamM3\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# ...

# %%
pd.merge(df1, df2)
# Out:
# Empty DataFrame
# Columns: [PO_Date, PO_Number, Item_ID, Item_Description, Manufacturer_Name, Manufacturer_ID, Lowest_Unit_Of_Measure, Purchasing_Unit_Of_Measure, Vendor_Name, Vendor_ID, Vendor_City, Vendor_Active_Status, Contract_ID, Contract_Description, Contract_Type, Contract_Start_Date, Contract_End_Date, Contract_Price(Million) , Contract_UOM, Unit_Of_Measure, Unit_Of_Measure_In_Number, Quantity_(at_UOM), Price_Per_UOM ($), Total_Price ($), Department, New_Vendor_Name]
# Index: []
#
# [0 rows x 26 columns]

# %%
print(dir(pd))
# Out:
# ['Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Float64Index', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int64Index', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NaT', 'Panel', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseArray', 'SparseDataFrame', 'SparseDtype', 'SparseSeries', 'TimeGrouper', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt64Index', 'UInt8Dtype', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_hashtable', '_lib', '_libs', '_np_version_under1p13', '_np_version_under1p14', '_np_version_under1p15', '_np_version_under1p16', '_np_version_under1p17', '_tslib', '_version', 'api', 'array', 'arrays', 'bdate_ra
# ...

# %%
df5 = pd.concat([df1,df2,df3,df4])
df.shape
# Out:
# (1000, 25)

# %%
df5.to_csv("Vendor_Shuffling.csv")

# %%
df = pd.read_csv("Vendor_Shuffling.csv")
df.head()
# Out:
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# 1              315                     DZ                         DZ
# 2              372                     EA                         EA
# 3              351                     EA                         EA
# 4              347                     EA                         EA
#
#   Vendor_Name Vendor_ID  ... Contract_End_Date Contract_Price(Million)   \
# ...

# %%
df['Vendor_Name'] = df['New_Vendor_Name']

# %%
df = df.drop('New_Vendor_Name',axis=1)

# %%
df.head()
# Out:
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# 1              315                     DZ                         DZ
# 2              372                     EA                         EA
# 3              351                     EA                         EA
# 4              347                     EA                         EA
#
#   Vendor_Name Vendor_ID  ... Contract_Start_Date Contract_End_Date  \
# 0     WellSky      V135  ...          29-06-2021        26-11-2022
# ...

# %%
df1 = df.groupby(['Item_Description', 'Vendor_Name'])
df_test = df1.first()
df_test.to_csv("Item_Vendor.csv")

# %%
df['Vendor_Name'].nunique()
# Out:
# 20

# %%
df['Vendor_Name'].unique()
# Out:
# array(['WellSky', 'HealthXNet', 'FGA Inc', 'Quadax Inc', 'OmniSys',
#        'Etactics', 'Ability Network', 'Prevounce Health', 'Noble House',
#        'eSolutions', 'Experian Health Inc', 'Eligible Inc',
#        'Cerner Health Services HDX', 'myhELO', 'Toyon Associates Inc',
#        'Healthcare IP', 'Rivet', 'CompMed', 'Ritiko LLC',
#        'Prevounce Healt'], dtype=object)

# %%
df = pd.read_csv("Vendor_Shuffling.csv")
df.head()
# Out:
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# 1              315                     DZ                         DZ
# 2              372                     EA                         EA
# 3              351                     EA                         EA
# 4              347                     EA                         EA
#
#   Vendor_Name Vendor_ID  ... Contract_End_Date Contract_Price(Million)   \
# ...

# %%
df['Vendor_Name'] = df['New_Vendor_Name']

# %%
df.head()
# Out:
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# 1              315                     DZ                         DZ
# 2              372                     EA                         EA
# 3              351                     EA                         EA
# 4              347                     EA                         EA
#
#   Vendor_Name Vendor_ID  ... Contract_End_Date Contract_Price(Million)   \
# ...

# %%
df = df.drop("New_Vendor_Name", axis = 1)
df.head()
# Out:
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# 1              315                     DZ                         DZ
# 2              372                     EA                         EA
# 3              351                     EA                         EA
# 4              347                     EA                         EA
#
#   Vendor_Name Vendor_ID  ... Contract_Start_Date Contract_End_Date  \
# 0     WellSky      V135  ...          29-06-2021        26-11-2022
# ...

# %%
df['Vendor_Name'].unique()
# Out:
# array(['WellSky', 'HealthXNet', 'FGA Inc', 'Quadax Inc', 'OmniSys',
#        'Etactics', 'Ability Network', 'Prevounce Health', 'Noble House',
#        'eSolutions', 'Experian Health Inc', 'Eligible Inc',
#        'Cerner Health Services HDX', 'myhELO', 'Greenway Health',
#        'Toyon Associates Inc', 'Healthcare IP', 'Rivet', 'CompMed',
#        'Ritiko LLC', 'Prevounce Healt'], dtype=object)

# %%
df['Vendor_Name'].nunique()
# Out:
# 21

# %%
df.shape
# Out:
# (1000, 25)

# %%
df['Vendor_ID'] = df['Vendor_Name'].map({'WellSky':"V135", 'HealthXNet':"V672", 'FGA Inc':"V522", 'Quadax Inc':"V797", 'OmniSys':"V486",
       'Etactics':"V658", 'Ability Network':"V565", 'Prevounce Health':"V453", 'Noble House':"V878",
       'eSolutions':"V222", 'Experian Health Inc':"V971", 'Eligible Inc':"V624",
       'Cerner Health Services HDX':"V090", 'myhELO':"V501", 'Greenway Health':"V213",
       'Toyon Associates Inc':"V928", 'Healthcare IP':"V653", 'Rivet':"V305", 'CompMed':"V425",
       'Ritiko LLC':"V754", 'Prevounce Healt':"V453"})

# %%
df['Vendor_ID'].unique()
# Out:
# array(['V135', 'V672', 'V522', 'V797', 'V486', 'V658', 'V565', 'V453',
#        'V878', 'V222', 'V971', 'V624', 'V090', 'V501', 'V213', 'V928',
#        'V653', 'V305', 'V425'], dtype=object)

# %%
df['Vendor_ID'].nunique()
# Out:
# 19

# %%
{'WellSky':"V135", 'HealthXNet':"V672", 'FGA Inc':"V522", 'Quadax Inc':"V797", 'OmniSys':"V486",
       'Etactics':"V658", 'Ability Network':"V565", 'Prevounce Health':"V453", 'Noble House':"V878",
       'eSolutions':"V222", 'Experian Health Inc':"V971", 'Eligible Inc':"V624",
       'Cerner Health Services HDX':"V090", 'myhELO':"V501", 'Greenway Health':"V213",
       'Toyon Associates Inc':"V928", 'Healthcare IP':"V653", 'Rivet':"V305", 'CompMed':"V425",
       'Ritiko LLC':"V754", 'Prevounce Healt':"V453"}

# %%
df['Vendor_City'].unique()
# Out:
# array(['New York', 'Los Angeles', 'Chicago', 'Phoenix', 'Houston',
#        'Oklahoma City', 'Denver', 'Salt Lake City', 'Miami', 'Atlanta',
#        'Dallas', 'Charlotte', 'San Antonio'], dtype=object)

# %%
df['Vendor_City'].nunique()
# Out:
# 13

# %%
{'WellSky':"New York", 'HealthXNet':"Los Angeles", 'FGA Inc':"Chicago", 'Quadax Inc':"Phoenix", 'OmniSys':"Houston",
       'Etactics':"Oklahoma City", 'Ability Network':"Denver", 'Prevounce Health':"Salt Lake City", 'Noble House':"Miami",
       'eSolutions':"Chicago", 'Experian Health Inc':"Charlotte", 'Eligible Inc':"Los Angeles",
       'Cerner Health Services HDX':"New York", 'myhELO':"Atlanta", 'Greenway Health':"Salt Lake City",
       'Toyon Associates Inc':"Dallas", 'Healthcare IP':"Charlotte", 'Rivet':"San Antonio", 'CompMed':"Houston",
       'Ritiko LLC':"Salt Lake City", 'Prevounce Healt':"Chicago"}

# %%
df['Vendor_City'] = df['Vendor_Name'].map({'WellSky':"New York", 'HealthXNet':"Los Angeles", 'FGA Inc':"Chicago", 'Quadax Inc':"Phoenix", 'OmniSys':"Houston",
       'Etactics':"Oklahoma City", 'Ability Network':"Denver", 'Prevounce Health':"Salt Lake City", 'Noble House':"Miami",
       'eSolutions':"Chicago", 'Experian Health Inc':"Charlotte", 'Eligible Inc':"Los Angeles",
       'Cerner Health Services HDX':"New York", 'myhELO':"Atlanta", 'Greenway Health':"Salt Lake City",
       'Toyon Associates Inc':"Dallas", 'Healthcare IP':"Charlotte", 'Rivet':"San Antonio", 'CompMed':"Houston",
       'Ritiko LLC':"Salt Lake City", 'Prevounce Healt':"Chicago"})

# %%
df[["Vendor_Name","Vendor_City"]].head()
# Out:
#   Vendor_Name  Vendor_City
# 0     WellSky     New York
# 1  HealthXNet  Los Angeles
# 2     FGA Inc      Chicago
# 3  Quadax Inc      Phoenix
# 4     OmniSys      Houston

# %%
df.head()
# Out:
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# 1              315                     DZ                         DZ
# 2              372                     EA                         EA
# 3              351                     EA                         EA
# 4              347                     EA                         EA
#
#   Vendor_Name Vendor_ID  ... Contract_Start_Date Contract_End_Date  \
# 0     WellSky      V135  ...          29-06-2021        26-11-2022
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
# PO_Date                       1000 non-null object
# PO_Number                     1000 non-null object
# Item_ID                       1000 non-null object
# Item_Description              1000 non-null object
# Manufacturer_Name             1000 non-null object
# Manufacturer_ID               1000 non-null int64
# Lowest_Unit_Of_Measure        1000 non-null object
# Purchasing_Unit_Of_Measure    1000 non-null object
# Vendor_Name                   1000 non-null object
# Vendor_ID                     1000 non-null object
# Vendor_City                   1000 non-null object
# Vendor_Active_Status          1000 non-null object
# Contract_ID                   1000 non-null int64
# Contract_Description          1000 non-null object
# Contract_Type                 1000 non-null object
# Contract_Start_Date           1000 non-null object
# ...

# %%
df['Contract_ID'].unique()
# Out:
# array([1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1018,
#        1012, 1013, 1014, 1015, 1016, 1017, 1019, 1020], dtype=int64)

# %%
df['Contract_ID'].nunique()
# Out:
# 19

# %%
{'WellSky':"1001", 'HealthXNet':"1002", 'FGA Inc':"1003", 'Quadax Inc':"1004", 'OmniSys':"1005",
       'Etactics':"1006", 'Ability Network':"1007", 'Prevounce Health':"1008", 'Noble House':"1009",
       'eSolutions':"1010", 'Experian Health Inc':"1011", 'Eligible Inc':"1012",
       'Cerner Health Services HDX':"1013", 'myhELO':"1014", 'Greenway Health':"1015",
       'Toyon Associates Inc':"1016", 'Healthcare IP':"1017", 'Rivet':"1018", 'CompMed':"1019",
       'Ritiko LLC':"1020", 'Prevounce Healt':"1008"}

# %%
df['Contract_ID'] = df['Vendor_Name'].map({'WellSky':"1001", 'HealthXNet':"1002", 'FGA Inc':"1003", 'Quadax Inc':"1004", 'OmniSys':"1005",
       'Etactics':"1006", 'Ability Network':"1007", 'Prevounce Health':"1008", 'Noble House':"1009",
       'eSolutions':"1010", 'Experian Health Inc':"1011", 'Eligible Inc':"1012",
       'Cerner Health Services HDX':"1013", 'myhELO':"1014", 'Greenway Health':"1015",
       'Toyon Associates Inc':"1016", 'Healthcare IP':"1017", 'Rivet':"1018", 'CompMed':"1019",
       'Ritiko LLC':"1020", 'Prevounce Healt':"1008"})

# %%
df[['Vendor_Name','Contract_ID']].head()
# Out:
#   Vendor_Name Contract_ID
# 0     WellSky        1001
# 1  HealthXNet        1002
# 2     FGA Inc        1003
# 3  Quadax Inc        1004
# 4     OmniSys        1005

# %%
df["Contract_Type"].value_counts()
# Out:
# FP    582
# TM    382
# CR     36
# Name: Contract_Type, dtype: int64

# %%
({'WellSky':"FP", 'HealthXNet':"TM", 'FGA Inc':"FP", 'Quadax Inc':"CR", 'OmniSys':"FP",
       'Etactics':"TM", 'Ability Network':"FP", 'Prevounce Health':"TM", 'Noble House':"TM",
       'eSolutions':"FP", 'Experian Health Inc':"FP", 'Eligible Inc':"TM",
       'Cerner Health Services HDX':"FP", 'myhELO':"TM", 'Greenway Health':"FP",
       'Toyon Associates Inc':"TM", 'Healthcare IP':"CR", 'Rivet':"CR", 'CompMed':"FP",
       'Ritiko LLC':"FP", 'Prevounce Healt':"TM"})

# %%
df['Contract_Type'] = df['Vendor_Name'].map({'WellSky':"FP", 'HealthXNet':"TM", 'FGA Inc':"FP", 'Quadax Inc':"CR", 'OmniSys':"FP",
       'Etactics':"TM", 'Ability Network':"FP", 'Prevounce Health':"TM", 'Noble House':"TM",
       'eSolutions':"FP", 'Experian Health Inc':"FP", 'Eligible Inc':"TM",
       'Cerner Health Services HDX':"FP", 'myhELO':"TM", 'Greenway Health':"FP",
       'Toyon Associates Inc':"TM", 'Healthcare IP':"CR", 'Rivet':"CR", 'CompMed':"FP",
       'Ritiko LLC':"FP", 'Prevounce Healt':"TM"})

# %%
df[['Vendor_Name','Contract_Type']].head()
# Out:
#   Vendor_Name Contract_Type
# 0     WellSky            FP
# 1  HealthXNet            TM
# 2     FGA Inc            FP
# 3  Quadax Inc            CR
# 4     OmniSys            FP

# %%
df['Contract_Start_Date'].unique()
# Out:
# array(['29-06-2021', '08-05-2021', '26-02-2021', '12-05-2021',
#        '23-07-2021', '30-05-2021', '06-10-2021', '22-04-2021',
#        '18-03-2021', '12-06-2021', '14-11-2021', '13-06-2021',
#        '24-01-2021', '06-07-2021', '20-01-2021', '29-05-2021',
#        '28-07-2021', '16-10-2021', '28-04-2021'], dtype=object)

# %%
({'WellSky':"29-06-2021", 'HealthXNet':"08-05-2021", 'FGA Inc':"26-02-2021", 'Quadax Inc':"12-05-2021", 'OmniSys':"23-07-2021",
       'Etactics':"30-05-2021", 'Ability Network':"30-05-2021", 'Prevounce Health':"06-10-2021", 'Noble House':"22-04-2021",
       'eSolutions':"18-03-2021", 'Experian Health Inc':"12-06-2021", 'Eligible Inc':"14-11-2021",
       'Cerner Health Services HDX':"13-06-2021", 'myhELO':"24-01-2021", 'Greenway Health':"06-07-2021",
       'Toyon Associates Inc':"20-01-2021", 'Healthcare IP':"29-05-2021", 'Rivet':"28-07-2021", 'CompMed':"16-10-2021",
       'Ritiko LLC':"28-04-2021", 'Prevounce Healt':"06-10-2021"})

# %%
df['Contract_Start_Date'] = df['Vendor_Name'].map({'WellSky':"29-06-2021", 'HealthXNet':"08-05-2021", 'FGA Inc':"26-02-2021", 'Quadax Inc':"12-05-2021", 'OmniSys':"23-07-2021",
       'Etactics':"30-05-2021", 'Ability Network':"30-05-2021", 'Prevounce Health':"06-10-2021", 'Noble House':"22-04-2021",
       'eSolutions':"18-03-2021", 'Experian Health Inc':"12-06-2021", 'Eligible Inc':"14-11-2021",
       'Cerner Health Services HDX':"13-06-2021", 'myhELO':"24-01-2021", 'Greenway Health':"06-07-2021",
       'Toyon Associates Inc':"20-01-2021", 'Healthcare IP':"29-05-2021", 'Rivet':"28-07-2021", 'CompMed':"16-10-2021",
       'Ritiko LLC':"28-04-2021", 'Prevounce Healt':"06-10-2021"})

# %%
df['Contract_End_Date'].nunique()
# Out:
# 19

# %%
({'WellSky':"26-11-2022", 'HealthXNet':"04-05-2022", 'FGA Inc':"31-07-2022", 'Quadax Inc':"12-11-2022", 'OmniSys':"17-08-2022",
       'Etactics':"07-02-2023", 'Ability Network':"21-09-2022", 'Prevounce Health':"05-01-2023", 'Noble House':"02-10-2022",
       'eSolutions':"10-12-2022", 'Experian Health Inc':"19-11-2022", 'Eligible Inc':"17-01-2023",
       'Cerner Health Services HDX':"31-11-2021", 'myhELO':"01-08-2022", 'Greenway Health':"07-10-2022",
       'Toyon Associates Inc':"29-08-2022", 'Healthcare IP':"06-11-2022", 'Rivet':"02-12-2022", 'CompMed':"25-10-2022'",
       'Ritiko LLC':"26-10-2022", 'Prevounce Healt':"05-01-2023"})

# %%
df['Contract_End_Date'] = df['Vendor_Name'].map({'WellSky':"26-11-2022", 'HealthXNet':"04-05-2022", 'FGA Inc':"31-07-2022", 'Quadax Inc':"12-11-2022", 'OmniSys':"17-08-2022",
       'Etactics':"07-02-2023", 'Ability Network':"21-09-2022", 'Prevounce Health':"05-01-2023", 'Noble House':"02-10-2022",
       'eSolutions':"10-12-2022", 'Experian Health Inc':"19-11-2022", 'Eligible Inc':"17-01-2023",
       'Cerner Health Services HDX':"31-11-2021", 'myhELO':"01-08-2022", 'Greenway Health':"07-10-2022",
       'Toyon Associates Inc':"29-08-2022", 'Healthcare IP':"06-11-2022", 'Rivet':"02-12-2022", 'CompMed':"25-10-2022'",
       'Ritiko LLC':"26-10-2022", 'Prevounce Healt':"05-01-2023"})

# %%
df.head()
# Out:
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# 1              315                     DZ                         DZ
# 2              372                     EA                         EA
# 3              351                     EA                         EA
# 4              347                     EA                         EA
#
#   Vendor_Name Vendor_ID  ... Contract_Start_Date Contract_End_Date  \
# 0     WellSky      V135  ...          29-06-2021        26-11-2022
# ...

# %%
df['Contract_Description'].unique()
# Out:
# array(['enim in', 'est congue', 'pellentesque volutpat', 'morbi',
#        'libero', 'duis faucibus', 'convallis', 'mattis egestas metus',
#        'tincidunt', 'aenean fermentum', 'proin at',
#        'massa volutpat convallis', 'enim', 'pretium quis lectus',
#        'sagittis sapien cum', 'metus sapien', 'in hac habitasse platea',
#        'quam pharetra magna ac', 'viverra dapibus'], dtype=object)

# %%
({'WellSky':"enim in", 'HealthXNet':"est congue", 'FGA Inc':"pellentesque volutpat", 'Quadax Inc':"morbi", 'OmniSys':"libero",
       'Etactics':"duis faucibus", 'Ability Network':"convallis", 'Prevounce Health':"mattis egestas metus", 'Noble House':"mattis egestas metus",
       'eSolutions':"enim", 'Experian Health Inc':"pretium quis lectus", 'Eligible Inc':"sagittis sapien cum",
       'Cerner Health Services HDX':"metus sapien", 'myhELO':"in hac habitasse platea", 'Greenway Health':"quam pharetra magna ac",
       'Toyon Associates Inc':"asd sft sgs", 'Healthcare IP':"sg vdh ddv", 'Rivet':"gfjb dghg the", 'CompMed':"erfcgf",
       'Ritiko LLC':"viverra dapibus", 'Prevounce Healt':"mattis egestas metus"})

# %%
df['Contract_Description'] = df['Vendor_Name'].map({'WellSky':"enim in", 'HealthXNet':"est congue", 'FGA Inc':"pellentesque volutpat", 'Quadax Inc':"morbi", 'OmniSys':"libero",
       'Etactics':"duis faucibus", 'Ability Network':"convallis", 'Prevounce Health':"mattis egestas metus", 'Noble House':"mattis egestas metus",
       'eSolutions':"enim", 'Experian Health Inc':"pretium quis lectus", 'Eligible Inc':"sagittis sapien cum",
       'Cerner Health Services HDX':"metus sapien", 'myhELO':"in hac habitasse platea", 'Greenway Health':"quam pharetra magna ac",
       'Toyon Associates Inc':"asd sft sgs", 'Healthcare IP':"sg vdh ddv", 'Rivet':"gfjb dghg the", 'CompMed':"erfcgf",
       'Ritiko LLC':"viverra dapibus", 'Prevounce Healt':"mattis egestas metus"})

# %%
df.head()
# Out:
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# 1              315                     DZ                         DZ
# 2              372                     EA                         EA
# 3              351                     EA                         EA
# 4              347                     EA                         EA
#
#   Vendor_Name Vendor_ID  ... Contract_Start_Date Contract_End_Date  \
# 0     WellSky      V135  ...          29-06-2021        26-11-2022
# ...

# %%
df.to_csv("Vendor_Master_Update.csv")

# %%
{"Stethscope":'Non-Consumable',
"Scissor":"Non-Consumable",
"Stretcher":"Non-Consumable",
"Magnifier":'Non-Consumable',
"Weighing Scale":'Consumable',
"Torch":'Non-Consumable',
"Face Mask":'Consumable',
"First Aid Kit":'Consumable',
"Gloves":'Consumable',
"Scalpel":'Consumable',
"Microscope":'Non-Consumable',
"Otoscope":'Non-Consumable',
"Thermometer":'Non-Consumable',
"Saline Bag":'Consumable',
"Syringe":'Consumable',
"X-ray Machine":'Non-Consumable',
"Bandage":'Consumable',
"Crutches":'Non-Consumable',
"Plaster":'Consumable',
"Cotton Wool":'Consumable',
"Surgical Mask":'Consumable',
"Oxygen Mask":'Consumable',
"Dropper":'Consumable',
"Needle":'Consumable',
"Cane":'Non-Consumable',
"Surgical Clamps":'Consumable',
"Forceps":'Consumable',
"Surgical Table":'Non-Consumable',
"Utility Table":'Non-Consumable',
"Instrument Table":'Non-Consumable',
"Ventilator":'Non-Consumable',
"Mayo Stands":'Non-Consumable',
"Kickbuckets":'Non-Consumable',
"Arm Supports":'Non-Consumable',
"Medical Syringe Infusion":'Consumable',
"Pacemakers":'Consumable',
"Defibrillators":'Non-Consumable',
"Wheelchairs":'Non-Consumable',
"Traction Equipment":'Non-Consumable',
"Needle Holder":'Consumable',
"Medicine Cup":'Consumable',
"Gauze":'Consumable',
"Trays":'Consumable',
"Cotton Swabs":'Consumable',
"Surgical lights":'Consumable',
"Anesthesia machine":'Non-Consumable',
"Walkers":'Non-Consumable',
"Tourniquet":'Consumable',
"Splints":'Consumable',
"Slings":'Consumable',
"ECG Machine":'Non-Consumable',
"Nebulizers":'Non-Consumable',
"Sutures":'Consumable',
"Braces":'Consumable'
}

# %%
import pandas as pd

# %%
df = pd.read_csv("Final_Dataset_V5.csv",encoding= 'unicode_escape')
df.head()
# Out:
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# 1              315                     DZ                         DZ
# 2              372                     EA                         EA
# 3              351                     EA                         EA
# 4              347                     EA                         EA
#
#   Vendor_Name Vendor_ID  ... Contract_End_Date Contract_Price Contract_UOM  \
# ...

# %%
df['Item_Type'] = df['Item_Description']

# %%
df.head()
# Out:
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# 1              315                     DZ                         DZ
# 2              372                     EA                         EA
# 3              351                     EA                         EA
# 4              347                     EA                         EA
#
#   Vendor_Name Vendor_ID  ... Contract_Price Contract_UOM Unit_Of_Measure  \
# ...

# %%
df['Item_Type'] = df['Item_Type'].map({"Stethscope":'Non-Consumable',
"Scissor":"Non-Consumable",
"Stretcher":"Non-Consumable",
"Magnifier":'Non-Consumable',
"Weighing Scale":'Non-Consumable',
"Torch":'Non-Consumable',
"Face Mask":'Consumable',
"First Aid Kit":'Consumable',
"Gloves":'Consumable',
"Scalpel":'Consumable',
"Microscope":'Non-Consumable',
"Otoscope":'Non-Consumable',
"Thermometer":'Non-Consumable',
"Saline Bag":'Consumable',
"Syringe":'Consumable',
"X-ray Machine":'Non-Consumable',
"Bandage":'Consumable',
"Crutches":'Non-Consumable',
"Plaster":'Consumable',
"Cotton Wool":'Consumable',
"Surgical Mask":'Consumable',
"Oxygen Mask":'Consumable',
"Dropper":'Consumable',
"Needle":'Consumable',
"Cane":'Non-Consumable',
"Surgical Clamps":'Consumable',
"Forceps":'Consumable',
"Surgical Table":'Non-Consumable',
"Utility Table":'Non-Consumable',
"Instrument Table":'Non-Consumable',
"Ventilator":'Non-Consumable',
"Mayo Stands":'Non-Consumable',
"Kickbuckets":'Non-Consumable',
"Arm Supports":'Non-Consumable',
"Medical Syringe Infusion":'Consumable',
"Pacemakers":'Consumable',
"Defibrillators":'Non-Consumable',
"Wheelchairs":'Non-Consumable',
"Traction Equipment":'Non-Consumable',
"Needle Holder":'Consumable',
"Medicine Cup":'Consumable',
"Gauze":'Consumable',
"Trays":'Consumable',
"Cotton Swabs":'Consumable',
"Surgical lights":'Non-Consumable',
"Anesthesia machine":'Non-Consumable',
"Walkers":'Non-Consumable',
"Tourniquet":'Consumable',
"Splints":'Consumable',
"Slings":'Consumable',
"ECG Machine":'Non-Consumable',
"Nebulizers":'Non-Consumable',
"Sutures":'Consumable',
"Braces":'Consumable'})

# %%
df.head()
# Out:
#       PO_Date PO_Number Item_ID Item_Description  Manufacturer_Name  \
# 0  22-06-2022    PO0001     IT1       Stethscope  Johnson & Johnson
# 1  11-08-2022    PO0002     IT2          Scissor           Teleflex
# 2  24-08-2021    PO0003     IT3        Stretcher         3M Company
# 3  31-05-2021    PO0004     IT4        Magnifier             Terumo
# 4  13-11-2022    PO0005     IT5   Weighing Scale              Nipro
#
#    Manufacturer_ID Lowest_Unit_Of_Measure Purchasing_Unit_Of_Measure  \
# 0              301                     EA                         EA
# 1              315                     DZ                         DZ
# 2              372                     EA                         EA
# 3              351                     EA                         EA
# 4              347                     EA                         EA
#
#   Vendor_Name Vendor_ID  ... Contract_Price Contract_UOM Unit_Of_Measure  \
# ...

# %%
df['Item_Type'].value_counts()
# Out:
# Consumable        508
# Non-Consumable    492
# Name: Item_Type, dtype: int64

# %%
df[['Item_Description',"Item_Type"]].head(54)
# Out:
#             Item_Description       Item_Type
# 0                 Stethscope  Non-Consumable
# 1                    Scissor  Non-Consumable
# 2                  Stretcher  Non-Consumable
# 3                  Magnifier  Non-Consumable
# 4             Weighing Scale  Non-Consumable
# 5                      Torch  Non-Consumable
# 6                  Face Mask      Consumable
# 7              First Aid Kit      Consumable
# 8                     Gloves      Consumable
# 9                    Scalpel      Consumable
# 10                Microscope  Non-Consumable
# 11                  Otoscope  Non-Consumable
# 12               Thermometer  Non-Consumable
# 13                Saline Bag      Consumable
# 14                   Syringe      Consumable
# 15             X-ray Machine  Non-Consumable
# 16                   Bandage      Consumable
# 17                  Crutches  Non-Consumable
# 18                   Plaster      Consumable
# 19               Cotton Wool      Consumable
# ...

# %%
df.to_csv("Final_Dataset_V6.csv")
